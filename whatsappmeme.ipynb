# %%
import glob
from IPython.display import Image
import random

# %%
imgfiles=glob.glob('images/*_வாட்ஸாப்ப்_-இல்_சுட்*')
print(len(imgfiles))
r=random.choice(imgfiles)
print(r)
Image(r)
# Out:
# 181
# images\84017_வாட்ஸாப்ப்_-இல்_சுட்_9991545281580147579749453412dcb32ea8-5541-42e7-9527-c22499d0c069.jpg
